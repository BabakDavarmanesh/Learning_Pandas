# %% [markdown]
# <a href="https://colab.research.google.com/github/BabakDavarmanesh/Learning_Pandas/blob/main/Learning_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color=darkblue>**Pandas Tutorial: A Beginner-Friendly Guide to Data Analysis**</font>
#
# **Author:** *Babak Davarmanesh*
#
# This document is licensed under a <a href="https://creativecommons.org/licenses/by/4.0/legalcode" target="_blank">Creative Commons Attribution 4.0 International (CC BY 4.0) license.</a>
#
#
# ---

# %% [markdown]
# # <font color=orange>**DataFrame**</font>

# %% [markdown]
# **Creating a DataFrame with Pandas**
#
# In this example, we are going to create a simple DataFrame using pandas, which is a powerful data manipulation library in Python.
#
# First, we import pandas using the alias pd. This is the standard practice in Python when working with pandas.

# %%
import pandas as pd

# %% [markdown]
# **Creating the DataFrame**
#
# We create a DataFrame using the pd.DataFrame() function, which takes a dictionary of lists (or arrays) as input. In this case, we have three columns: Name, Age, and Sex.

# %%
df = pd.DataFrame(
    {
        "Name": [
                 "Braund, Mr. Owen Harris",
                 "Allen, Mr. William Henry",
                 "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)

# %% [markdown]
# **Displaying the DataFrame**
#
# After creating the DataFrame, we can display it in two ways:
#
# Using the print() function:

# %%
print(df)
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %% [markdown]
# **Accessing a Single Column**
#
# If you want to access a specific column from the DataFrame, such as the Name column, you can do so by referencing the column name inside square brackets:
#
# This will return a Series, which is essentially a single column of the DataFrame. The output will look like this:

# %%
df["Name"]
# Out:
# 0     Braund, Mr. Owen Harris
# 1    Allen, Mr. William Henry
# 2    Bonnell, Miss. Elizabeth
# Name: Name, dtype: object

# %% [markdown]
# **Creating and Working with a Pandas Series**
#
# Sometimes, we don't need to create an entire DataFrame. Instead, we can create a pandas Series, which is essentially a single column of data. This can be useful when you only need to work with one set of values.
#
# You can create a Series like this:

# %%
MyCol  = pd.Series(["Canada", "USA", "Germany"], name="Nationality")
MyCol
# Out:
# 0     Canada
# 1        USA
# 2    Germany
# Name: Nationality, dtype: object

# %% [markdown]
# **Using Functions like max() on DataFrames and Series**
#
# In pandas, both DataFrames and Series support a variety of functions that allow you to perform operations directly on the data.
#
# For example, we can use the max() function to find the maximum value in a column of a DataFrame or in a Series.
#
# **On DataFrame Column**
#
# If you want to find the maximum value in a specific column of a DataFrame, you can access the column and apply the max() function like this:

# %%
df['Age'].max()
# Out:
# 58

# %% [markdown]
# Here:
#
# `df['Age']` accesses the Age column of the DataFrame df.
#
# `.max()` then returns the maximum value from that column.
#
# For example, if the Age column contains [22, 35, 58], calling `df['Age'].max() `will return: 58

# %% [markdown]
# On Series
#
# Similarly, you can use the `max()` function on a Series as well:
#
# In this case, the function determines the "maximum" value based on alphabetical order.

# %%
MyCol.max()
# Out:
# 'USA'

# %% [markdown]
# The `.min()` function in pandas is used to find the minimum value in a column. When applied to a specific column, such as df['Age'], it returns the smallest value in that column.

# %%
df['Age'].min()
# Out:
# 22

# %%
MyCol.min()
# Out:
# 'Canada'

# %% [markdown]
# ---

# %% [markdown]
# **Using df.describe() for Data Summary**
#
# In pandas, we can use the describe() function to generate a statistical summary of a DataFrame. This function provides useful insights into the numerical columns of the dataset.
#
# **What Does describe() Do?**
# The describe() function calculates and displays the following statistics for all numerical columns in the DataFrame:
#
# count: The number of non-null values.
#
# mean: The average value.
#
# std: The standard deviation (spread of data).
#
# min: The smallest value.
#
# 25% (Q1): The first quartile (25th percentile).
#
# 50% (median or Q2): The middle value (50th percentile).
#
# 75% (Q3): The third quartile (75th percentile).
#
# max: The largest value.

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %% [markdown]
# **describe() Works Only on Numerical Columns**
#
# The describe() function in pandas only works on numerical columns by default. If a column contains non-numeric data (such as strings), it will be ignored.
#
# Let's demonstrate this with an example where we temporarily modify a value in the Age column and then revert it back.

# %%
df['Age'].iloc[1] = None

# %%
df
# Out:
#                        Name   Age     Sex
# 0   Braund, Mr. Owen Harris  22.0    male
# 1  Allen, Mr. William Henry   NaN    male
# 2  Bonnell, Miss. Elizabeth  58.0  female

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   40.000000
# std    25.455844
# min    22.000000
# 25%    31.000000
# 50%    40.000000
# 75%    49.000000
# max    58.000000

# %%
df['Age'].iloc[1] = 35

# %% [markdown]
# **Using describe() on Non-Numerical Columns or Series**
#
# While describe() is mainly used for numerical columns, it also works on non-numerical (categorical or string) data. When applied to a Series of text values, it provides different summary statistics.
#
# *Explanation:*
#
# count: Number of non-null values (ignores None or NaN).
#
# unique: Number of unique values in the Series (a, b, and c → 3 unique values).
#
# top: The most frequent value (a appears the most).
#
# freq: The frequency of the top value (a appears 2 times).

# %%
s = pd.Series(['a', 'b', 'c', 'a', 'b', None, 'c'])
s.describe()
# Out:
# count     6
# unique    3
# top       a
# freq      2
# dtype: object

# %% [markdown]
# **DataFrame.describe(include=...)**
#
# By default, it only includes numerical columns. However, we can specify different data types using the include parameter:
#
# `include="all"`
#
# Includes all columns, regardless of their data type (numerical, categorical, etc.).
#
# Non-numeric columns get statistics like count, unique, top (most frequent value), and frequency of the top value.
#
# Numeric columns get count, mean, standard deviation, min, max, and quartiles.
#
# `include="object"`
#
# Includes only categorical (string) columns.
#
# Provides statistics like count, unique values, most frequent value (top), and its frequency (freq).
#
# Does not include numerical statistics like mean or standard deviation.
#
# `include="number"`
#
# Includes only numerical columns.
#
# Provides statistics such as count, mean, std (standard deviation), min, 25th percentile, median (50th percentile), 75th percentile, and max.

# %%
frame = pd.DataFrame(
    {
        "col1": ["a" , "b", "c", "d"],
        "col2": [1,2,3,6]
    }
)

# %%
frame
# Out:
#   col1  col2
# 0    a     1
# 1    b     2
# 2    c     3
# 3    d     6

# %%
frame.describe(include="all")
# Out:
#        col1      col2
# count     4  4.000000
# unique    4       NaN
# top       a       NaN
# freq      1       NaN
# mean    NaN  3.000000
# std     NaN  2.160247
# min     NaN  1.000000
# 25%     NaN  1.750000
# 50%     NaN  2.500000
# 75%     NaN  3.750000
# max     NaN  6.000000

# %%
frame.describe(include="object")
# Out:
#        col1
# count     4
# unique    4
# top       a
# freq      1

# %%
frame.describe(include="number")
# Out:
#            col2
# count  4.000000
# mean   3.000000
# std    2.160247
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.750000
# max    6.000000

# %% [markdown]
# ---

# %% [markdown]
# **Understanding `idxmin()` and `idxmax()`**
#
# Pandas provides two useful methods for finding the index of the minimum and maximum values in a DataFrame:
#
# `idxmin()`: Returns the index of the smallest value in each column or row.
#
# `idxmax()`: Returns the index of the largest value in each column or row.
#
# Understanding axis=0 and axis=1
# In pandas, the axis parameter determines whether an operation works on columns or rows:
#
# axis Value	Meaning	Works On	Example
#
# \begin{array}{|c|c|c|c|}
# \hline
# \textbf{axis Value} & \textbf{Meaning} & \textbf{Works On} & \textbf{Example} \\
# \hline
# 0 & \text{Column-wise operation} & \text{ Works on each column independently} & \texttt{df.idxmin(axis=0)} \text{(Finds min index per column)} \\
# \hline
# 1 & \text{Row-wise operation} & \text{Works on each row independently} & \texttt{df.idxmax(axis=1)} \text{(Finds max index per row)} \\
# \hline
# \end{array}

# %%
import numpy as np

# %%
df1 = pd.DataFrame(np.random.randint(1, 100 ,size=(5,3)), columns=["A","B","C"])
df1
# Out:
#     A   B   C
# 0  51  16  54
# 1  91  46  19
# 2  41  97   7
# 3  63  92  19
# 4  22   9  94

# %%
df1.idxmin(axis=0)
# Out:
# A    4
# B    4
# C    2
# dtype: int64

# %%
df1.min(axis=0)
# Out:
# A    22
# B     9
# C     7
# dtype: int64

# %% [markdown]
# **Finding Minimum Values with `idxmin()` and `min()`**
#
# 1️⃣ Finding the index of the minimum value per column (axis=0)

# %%
min_indices = df1.idxmin(axis=0)  # Index of min value
min_values = df1.min(axis=0)  # Minimum values

# Combining into a DataFrame for better display
result = pd.concat([min_indices, min_values], axis=1)
result.columns = ["Index", "Min Value"]

print(result)
# Out:
#    Index  Min Value
# A      4         22
# B      4          9
# C      2          7

# %% [markdown]
# **Finding Maximum Values with `idxmax()` and `max()`**
#
# 2️⃣ Finding the index of the maximum value per row (axis=1)

# %%
max_indices = df1.idxmax(axis=1)  # Index of max value
max_values = df1.max(axis=1)  # Maximum values

# Combining into a DataFrame for better display
result = pd.concat([max_indices, max_values], axis=1)
result.columns = ["Index", "Max Value"]

print(result)
# Out:
#   Index  Max Value
# 0     C         54
# 1     A         91
# 2     B         97
# 3     B         92
# 4     C         94

# %% [markdown]
# # <font color=orange>**How do I read and write tabular data**</font>

# %% [markdown]
# Google Colab runs on cloud servers, so we need to mount Google Drive to access local files stored there.
#
# Once Google Drive is mounted, we can read a CSV file using Pandas
#
# We can use `.head()` to inspect the first few rows of the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv("/content/drive/My Drive/dataset/iris.csv")  # Adjust path if needed
df.head() # Default: Shows first 5 rows
# Out:
# Mounted at /content/drive
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.head(7)  # Shows first 7 rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa

# %% [markdown]
# **View the Last Few Rows**
#
# To see the last rows of the dataset, we use `.tail()`, which works similarly to .`head():`

# %%
df.tail(3) # Shows last 3 rows
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# **Adding a New Column with `.assign()`**
#
# We can create a new column without modifying the original DataFrame using .`assign():`

# %%
df.assign(sepal_ratio = df['sepal_length'] / df['sepal_width'] )
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      sepal_ratio
# 0       1.457143
# 1       1.633333
# 2       1.468750
# ...

# %% [markdown]
# Here, we use `lambda x` to define the calculation dynamically. The advantage is that Pandas handles the operation more efficiently.

# %%
df.assign(sepal_ratio = lambda x: (x['sepal_length'] / x['sepal_width']))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      sepal_ratio
# 0       1.457143
# 1       1.633333
# 2       1.468750
# ...

# %% [markdown]
# **Filtering Data with `.query()`**
#
# The `.query()` method allows filtering data using a string expression:

# %%
df.query('sepal_length > 7.5')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica

# %% [markdown]
# **Saving Data to Files**
#
# Saving as CSV
#
# To save the DataFrame as a CSV file in Google Drive.
#
# This will save the DataFrame as new_data.csv in the dataset folder of Google Drive.

# %%
df.to_csv("/content/drive/My Drive/dataset/new_data.csv")

# %% [markdown]
# **Saving as Excel**
#
# To save the DataFrame as an Excel file:
#
# sheet_name="temp" → Saves data in a sheet named "temp".
#
# index=False → Excludes the index column from the saved file.

# %%
df.to_excel("/content/drive/My Drive/dataset/new_data.xlsx", sheet_name="temp", index = False)

# %% [markdown]
# ![Google Drive.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # <font color=orange>**Selecting and Filtering Data in Pandas**</font>

# %% [markdown]
# 🟦 **1. `df.loc[0:2]` – Access rows by label (index name)**
#     `loc[]` is label-based indexing. It selects rows by index labels, not positions.
#
#     When you write 0:2, it includes both 0, 1, and 2 (it's inclusive).
#
#     Useful when your index contains meaningful labels (like dates or strings).
#
# 🟦 **2. `df.loc[0]` – Access a single row by label**
#     Returns the row with label 0.
#
#     Output is a Series, not a DataFrame.
#
#     You can think of this as one record.
#
# 🟦 **3. `df.iloc[0]` – Access a single row by position**
#     `.iloc[]` is position-based indexing.
#
#     `iloc[0]` means "give me the first row", regardless of the index label.
#
#     Very useful when you're working with raw data where index labels don’t matter.
#
# 🟦 **4. Filtering with Boolean Conditions**
#     Returns a Boolean Series showing which rows meet the condition.
#
#     Example output: True where `sepal_length > 7.5`, False otherwise.

# %%
print(df.loc[0:2])
print("------------------------------------------------------------------------")
print(df.loc[0])
print("------------------------------------------------------------------------")
print(df.iloc[0])
print("------------------------------------------------------------------------")
print(df.sepal_length > 7.5, end="\n\n")

print(df[df.sepal_length > 7.5])
print("------------------------------------------------------------------------")
print(df)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# ------------------------------------------------------------------------
# sepal_length            5.1
# sepal_width             3.5
# petal_length            1.4
# petal_width             0.2
# class           Iris-setosa
# Name: 0, dtype: object
# ------------------------------------------------------------------------
# sepal_length            5.1
# sepal_width             3.5
# petal_length            1.4
# petal_width             0.2
# class           Iris-setosa
# Name: 0, dtype: object
# ------------------------------------------------------------------------
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# ...

# %% [markdown]
# # <font color=orange>**Visulization in Pandas**</font>

# %% [markdown]
# **📘 Pandas DataFrame and Basic Plotting Tutorial**
#
# 🔹 Import the Required Libraries
# - pandas is used for data manipulation and analysis.
#
# - numpy is great for numerical operations (you didn’t use it directly yet, but it's good to have).
#
# matplotlib.pyplot helps you plot graphs and visualize data.
#
# Reference: [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# You’ve created a dictionary where:
#
# - "uneployment_rate" is your x-axis variable.
#
# - "stock_market_index" is your y-axis variable.
#
# Then converts the dictionary into a structured table (a DataFrame), making it easier to visualize and analyze.

# %%
data_scatt = {
    "unemployment_rate": [5.7, 5.3, 5.3, 5.3, 5.4, 5.6, 5.5],
    "stock_market_index": [1500, 1520, 1525, 1523, 1515, 1540, 1545]
}

df_scatt = pd.DataFrame(data_scatt)
df_scatt
# Out:
#    unemployment_rate  stock_market_index
# 0                5.7                1500
# 1                5.3                1520
# 2                5.3                1525
# 3                5.3                1523
# 4                5.4                1515
# 5                5.6                1540
# 6                5.5                1545

# %% [markdown]
# **🔹 Create a Scatter Plot**
#
# - `kind="scatter"` tells pandas to make a scatter plot.
#
# - `x` and `y` specify which columns to use for each axis.
#
# - `title` gives your chart a name.
#
# - `plt.show()` displays the plot.

# %%
df_scatt.plot(kind="scatter", x="unemployment_rate", y="stock_market_index", title="Scatter Plot")
plt.show()

# %% [markdown]
# **🔹 Create a Line Plot**
#
# This line creates a line plot using the same data.

# %%
df_scatt.plot(kind="line", x="unemployment_rate", y="stock_market_index", title="Line Plot")
plt.show()

# %%
data_bar ={
    'country': ['USA', 'Canada', 'Germany', 'UK', 'France'],
    'population': [328.2, 37.6, 83.1, 66.4, 67.2]
}

df_bar = pd.DataFrame(data_bar)
df_bar
# Out:
#    country  population
# 0      USA       328.2
# 1   Canada        37.6
# 2  Germany        83.1
# 3       UK        66.4
# 4   France        67.2

# %% [markdown]
# **🔹 Create a Bar Chart**
#
# - `kind="bar"` makes a vertical bar chart.
#
# - x = country names.
#
# - y = population numbers.
#
# - You added labels for both axes and a title to make the chart clear.

# %%
df_bar.plot(kind="bar", x="country", y="population", title="Population by Country")
plt.xlabel("Country")
plt.ylabel("Population (millions)")
plt.show()

# %% [markdown]
# Show data labels on bars (a little more advanced but looks great)

# %%
ax = df_bar.plot(kind="bar", x="country", y="population", color='skyblue', title="Population by Country")
for index, value in enumerate(df_bar['population']):
    ax.text(index, value + 1, str(value), ha='center')
plt.xlabel("Country")
plt.ylabel("Population (millions)")
plt.show()

# %% [markdown]
# **🥧 Pie Chart with Pandas**

# %%
data_pie = {
    'programming_language': ['Python', 'Java', 'JavaScript', 'C++', 'C#'],
    'popularity': [25.6, 18.5, 8.5, 7.2, 6.1]
}

df_pie = pd.DataFrame(data_pie)
df_pie
# Out:
#   programming_language  popularity
# 0               Python        25.6
# 1                 Java        18.5
# 2           JavaScript         8.5
# 3                  C++         7.2
# 4                   C#         6.1

# %% [markdown]
# **🔹 Create the Pie Chart**
#
# - `kind="pie"`: tells pandas to make a pie chart.
#
# - `y="popularity"`: values to plot.
#
# - `labels=df_pie['programming_language']`: sets the labels for each slice.
#
# - `autopct='%1.1f%%'`: shows the percentage on each slice with one decimal place.
#
# - `title="..."`: gives the chart a title.
#
# - `shadow=True`: adds a drop shadow for a 3D effect.

# %%
df_pie.plot(kind="pie", y="popularity", labels=df_pie['programming_language'],
            autopct='%1.1f%%', title="Pie Chart",shadow =True)
plt.show()

# %% [markdown]
# **📊 Creating a Stacked Bar Chart**

# %%
data_stackbar = {
    "date": ["2023-01-01","2023-01-01", "2023-01-02","2023-01-02", "2023-01-03", "2023-01-04", "2023-01-04"],
    "type": ["A", "A", "C", "B", "B", "C", "A"],
    "value": [10, 20, 15, 25, 30, 12, 5]
}

df_stackbar = pd.DataFrame(data_stackbar)
df_stackbar
# Out:
#          date type  value
# 0  2023-01-01    A     10
# 1  2023-01-01    A     20
# 2  2023-01-02    C     15
# 3  2023-01-02    B     25
# 4  2023-01-03    B     30
# 5  2023-01-04    C     12
# 6  2023-01-04    A      5

# %% [markdown]
# **Basic Bar Chart**
#
# This creates a bar chart using the raw data — not yet grouped

# %%
df_stackbar.plot(kind="bar", x="date", y="value", stacked=True, title="Stacked Bar Chart")
plt.show()

# %% [markdown]
# **Group Data by Date and Type**
#
# We first group the data by both date and type.Then we sum the values for each group.

# %%
df_stackbar.groupby(["date","type"]).sum().plot(kind="bar", title="Stacked Bar Chart")
# Out:
# <Axes: title={'center': 'Stacked Bar Chart'}, xlabel='date,type'>

# %% [markdown]
# **Unstack to Reorganize Data**
#
# - `.unstack()` pivots the data so that each type becomes its own column.
#
# - Now each date has multiple bars side by side (grouped bar chart).
#
# - The `y="value"` tells pandas which values to plot.

# %%
df_stackbar.groupby(["date","type"]).sum().unstack().plot(kind="bar", title="Stacked Bar Chart", y="value")
# Out:
# <Axes: title={'center': 'Stacked Bar Chart'}, xlabel='date'>

# %% [markdown]
# **Stacked Bar Chart**
#
# - This is the final version — a proper stacked bar chart.
#
# - Each bar represents a date, and segments inside the bar represent different types.
#
# - This is great for visualizing composition of total value by type for each date.

# %%
df_stackbar.groupby(["date","type"]).sum().unstack().plot(kind="bar", title="Stacked Bar Chart", y="value", stacked=True)
# Out:
# <Axes: title={'center': 'Stacked Bar Chart'}, xlabel='date'>

# %% [markdown]
# # <font color=orange>**How to create new columns derived from existing columns?**</font>

# %%
import seaborn as sns # is a statistical data visualization library, which also provides access to built-in datasets
import pandas as pd

# Load the dataset
titanic_df = sns.load_dataset('titanic')

# Save it as a CSV file
titanic_df.to_csv('titanic_dataset.csv', index=False) # index=False prevents pandas from writing the DataFrame index as a column
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# **🔹 Create a New Column Derived from an Existing One**
#
# - Creates a new column called New_Age by dividing the age column by 25.
#
# - This is a simple transformation example. You can perform arithmetic or apply custom functions to create new features.

# %%
titanic_df["New_Age"] = titanic_df["age"] / 25
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  New_Age
# 0    man        True  NaN  Southampton    no  False     0.88
# 1  woman       False    C    Cherbourg   yes  False     1.52
# 2  woman       False  NaN  Southampton   yes   True     1.04
# 3  woman       False    C  Southampton   yes  False     1.40
# 4    man        True  NaN  Southampton    no   True     1.40

# %% [markdown]
# **🔹 Rename Columns for Clarity**
#
# - Renames columns to start with uppercase letters (optional, for better readability).
#
# - who becomes Who, and age becomes Age.

# %%
titanic_df_renamed = titanic_df.rename(columns={"who": "Who", "age": "Age"})
titanic_df_renamed.head()
# Out:
#    survived  pclass     sex   Age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      Who  adult_male deck  embark_town alive  alone  New_Age
# 0    man        True  NaN  Southampton    no  False     0.88
# 1  woman       False    C    Cherbourg   yes  False     1.52
# 2  woman       False  NaN  Southampton   yes   True     1.04
# 3  woman       False    C  Southampton   yes  False     1.40
# 4    man        True  NaN  Southampton    no   True     1.40

# %% [markdown]
# # <font color=orange>**How to calculate summery statistics?**</font>

# %% [markdown]
# # <font color=orange>**Handel Time series**</font>
